# %% [markdown]
# # Data Visualisation with Bokeh

# %% [markdown]
# Bokeh is a Python interactive visualisation library designed for presentation on modern web browsers. The library’s main aims are as follows:
#
# •	To provide elegant, concise construction of basic exploratory and advanced custom graphics.
#
# •	To provide high-performance interactivity over very large or streaming data sets.
#
# To offer variety in the level of simplicity or complexity offered to the different users of Bokeh, three interface levels are exposed to the user:
#
# 1.	bokeh.models: A low-level interface which provides the most flexibility to application developers.
# 2.	bokeh.plotting: An intermediate-level interface which is focused on composing visual glyphs.
# 3.	bokeh.charts: A high-level interface designed to build complex statistical plots in a quick and simple manner.
#
# I am going to focus on the bokeh.plotting interface as this interface provides a nice middleground between the very high-level and very low-level.

# %% [markdown]
# ## bokeh.plotting

# %% [markdown]
# As mentioned above, the bokeh.plotting interface is a mid-level interface in the Bokeh library. It is focused on the visual glyphs (explored further below) that represent the user's data, while the putting together of plots with sensible default axes, grids, and tools is handled by Bokeh.
#
# The key class in the bokeh.plotting interface is the <i>Figure</i> class, which is a subclass of the <i>Plot</i> class. It contains methods for adding glyphs to the plot and also composes default axes, grids, and tools in the proper way without any extra effort. A Figure object can be created by calling the figure() function.
#
# Before you start any plotting, you must import the parts of the bokeh.plotting interface that you require for your program. For our example, we will require 3 methods:

# %%
from bokeh.plotting import figure, output_notebook, show

# %% [markdown]
# Once you have finished your imports, the basic steps to creating plots with the bokeh.plotting interface are as follows:
# -	Define the data that you are going to use to specify points on the plot. For our example, we will just assign some aribtrary numbers to be the x and y points, however in real life cases, you will naturally be using more meaningful data:

# %%
x_points = [1,2,3,4,5]
y_points = [2,3,4,1,1]

# %% [markdown]
# - Define where you want Bokeh to generate output. The two output methods we will be looking at are:
#
# >  <b>output_notebook():</b>  Displays the visualisations in Jupyter notebook cells.
#
# >  <b>output_file(filename):</b>  Generates a standalone, named HTML document which displays the Bokeh visualisation. This method's only mandatory argument is the name of the HTML document (in string form) that the user wishes to save the output to (e.g. "test.html").  Its optional arguments are <i>title, autosave, mode,</i> and <i>root_dir</i>.
#
# Both of the above methods actually belong to the <i>bokeh.io</i> interface but can also be imported from <i>bokeh.plotting</i> for the convenience of the user. Learn more about the methods and the default values of their optional arguments here: http://bokeh.pydata.org/en/latest/docs/reference/io.html.

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="087f59df-3c8c-42de-b9ac-469b0227dd5f">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# - Create a <i>Figure</i> object by calling the <i>figure()</i> method and assign it to a variable. Add some extras to your plot such as a title, tools, and axes labels by making use of the several optional parameters you can pass in to this method. To view the entire list of stylistic attributes you can include in the <i>figure()</i> method, take a look here: http://bokeh.pydata.org/en/latest/docs/user_guide/styling.html#plots; or if you would like to learn more about different ways of configuring the plot's toolbar, see here: http://bokeh.pydata.org/en/0.11.1/docs/user_guide/tools.html (<i>Note:</i> Since the <i>Figure</i> class is a sub-class of <i>Plot</i>, attributes and methods of plots are inherited.)

# %%
plot = figure(title="Our Example Plot", plot_height=500, plot_width=500, x_axis_label='Time', y_axis_label='Temperature')

# %% [markdown]
# If, at a later point, you want to add or change some attributes, you can do so as shown below:

# %%
plot.title_text_alpha=0.8
plot.border_fill_color='whitesmoke'

# %% [markdown]
# The next step is the most fundamental aspect of the <i>bokeh.plotting</i> interface: adding glyphs to the above plot using one or more of the many glyph-generating methods offered by the <i>Figure</i> class.
# > <b>Key Definition:</b> A <i>glyph</i> is a basic building block of Bokeh plots. Examples of glyphs include scatter markers, lines, patches, and wedges, amongst others.
#
# This ability to add various types of glyphs simply using methods is one of the most attractive aspects of the <i>bokeh.plotting</i> interface. It's simple, quick, and effective.
# For our first example, I am going to show you how to add a line glyph to a plot:

# %%
# Add a red line which passes through the co-ordinates assigned to the variables 'x_points' and 'y_points' above 
plot.line(x_points, y_points, line_width=3, line_color="red", line_alpha=0.5)

# %% [markdown]
# Finally, call either the <i>show()</i> or <i>save()</i> method, depending on whether you want to save and display the plot immediately or just save it. In our example, we will use <i>show()</i> as we want to be able to see our results.

# %%
show(plot)
# Out:
#     <div class="plotdiv" id="b724bc7b-ae8a-43f5-bdbd-6f7679b2f9d5"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b724bc7b-ae8a-43f5-bdbd-6f7679b2f9d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b724bc7b-ae8a-43f5-bdbd-6f7679b2f9d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c87ac8b1-ec35-4a13-9c58-d4bbc7085c5a":{"roots":{"references":[{"attributes":{},"id":"0e5a9aa8-ed04-477b-b300-ecdf9e4c803b","type":"ToolEvents"},{"attributes":{"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"}},"id":"ad87d4ed-fd19-41a3-956d-c6edc720d569","type":"ResetTool"},{"attributes":{"axis_label":"Time","formatter":{"id":"5c5be02e-c72e-478c-9fbd-07d9ca63849c","type":"BasicTickFormatter"},"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"2925fe37-a61e-483f-91bd-acc1b7acc28b","type":"BasicTicker"}},"id":"bb4ca360-b2bb-4e14-9a5d-54de94301038","type":"LinearAxis"},{"attributes":{},"id":"929e0a6b-96b6-48ee-8e2a-f0552c9a7f16","type":"BasicTicker"},{"attributes":{"callback":null},"id":"95535631-c7ec-4d3e-b985-472d7dca0782","type":"DataRange1d"},{"attributes":{"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"}},"id":"5a6e7534-d4e9-48de-a25b-786a3cacd883","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"929e0a6b-96b6-48ee-8e2a-f0552c9a7f16","type":"BasicTicker"}},"id":"3b6e1172-f36e-439e-a46b-099f0ae86542","type":"Grid"},{"attributes":{"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"}},"id":"7104ab24-d059-4653-874c-09f95fe2a43e","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"2925fe37-a61e-483f-91bd-acc1b7acc28b","type":"BasicTicker"}},"id":"11b11500-c55d-47fd-9845-0ab022209986","type":"Grid"},{"attributes":{"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"}},"id":"0caaf535-0209-4332-910b-798e3e4f4411","type":"HelpTool"},{"attributes":{"axis_label":"Temperature","formatter":{"id":"cfa1ec9c-9b44-476d-97fa-af0d68516d86","type":"BasicTickFormatter"},"plot":{"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"929e0a6b-96b6-48ee-8e2a-f0552c9a7f16","type":"BasicTicker"}},"id":"7256edb3-0084-4223-9721-4d56b4825691","type":"LinearAxis"},{"attributes":{},"id":"2925fe37-a61e-483f-91bd-acc1b7acc28b","type":"BasicTicker"},{"attributes":{"below":[{"id":"bb4ca360-b2bb-4e14-9a5d-54de94301038","type":"LinearAxis"}],"border_fill_color":{"value":"whitesmoke"},"left":[{"id":"7256edb3-0084-4223-9721-4d56b4825691","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"bb4ca360-b2bb-4e14-9a5d-54de94301038","type":"LinearAxis"},{"id":"11b11500-c55d-47fd-9845-0ab022209986","type":"Grid"},{"id":"7256edb3-0084-4223-9721-4d56b4825691","type":"LinearAxis"},{"id":"3b6e1172-f36e-439e-a46b-099f0ae86542","type":"Grid"},{"id":"8773654b-8c19-40d6-a25c-3d82acc5a843","type":"BoxAnnotation"},{"id":"ad7a811b-a2d8-41ee-b9c4-457ec4449ac0","type":"GlyphRenderer"}],"title":"Our Example Plot","title_text_alpha":{"value":0.8},"tool_events":{"id":"0e5a9aa8-ed04-477b-b300-ecdf9e4c803b","type":"ToolEvents"},"tools":[{"id":"8517f5c1-70dc-4573-bc20-d2696618f07e","type":"PanTool"},{"id":"5a6e7534-d4e9-48de-a25b-786a3cacd883","type":"WheelZoomTool"},{"id":"de3ca0b6-cd12-4b49-b1f0-7eadbf55d2a1","type":"BoxZoomTool"},{"id":"7104ab24-d059-4653-874c-09f95fe2a43e","type":"PreviewSaveTool"},{"id":"61a7286e-9520-40e0-a3e3-edf3b31d9bbc","type":"ResizeTool"},{"id":"ad87d4ed-fd19-41a3-956d-c6edc720d569","type":"ResetTool"},{"id":"0caaf535-0209-4332-910b-798e3e4f4411","type":"HelpTool"}],"x_range":{"id":"95535631-c7ec-4d3e-b985-472d7dca0782","type":"DataRange1d"},"y_range":{"id":"5270d3f5-b23d-44e4-9a20-a349259703a1","type":"DataRange1d"}},"id":"543daf20-123e-4fe3-b3f5-c842269a71b7","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"e477d5bb-4d56-450d-9dbf-fdc1fdee1396","type":"ColumnDataSource"},"glyph":{"id":"7caf0343-225c-4e9a-882a-5581449d4dd0","type":"Line"},"hover_glyph":null,"nonselectio ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %% [markdown]
# Above is the output of our program which displays a simple line graph, the co-ordinates of which correspond to those that we passed into the <i>line()</i> method of our <i>Figure</i> object.
# Let's add some square-shaped scatter markers into our plot using the <i>square()</i> method and then display it again using the <i>show()</i> method.

# %%
plot.square([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="olive", alpha=0.5)
show(plot)
# Out:
#     <div class="plotdiv" id="f428fe6b-fb74-478b-9c58-89b00be452b1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f428fe6b-fb74-478b-9c58-89b00be452b1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f428fe6b-fb74-478b-9c58-89b00be452b1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"181445dc-b86c-4b08-a076-3125f706ac4c":{"roots":{"references":[{"attributes":{"plot":{"id":"48791edc-c0bd-4498-881a-dc332d725641","subtype":"Figure","type":"Plot"}},"id":"9d6cc0c1-76bd-4cea-b737-4683e03c0402","type":"HelpTool"},{"attributes":{"data_source":{"id":"30089bc4-ae6d-4717-b6e8-a7d15b9459f0","type":"ColumnDataSource"},"glyph":{"id":"02e50846-9af6-439e-a47d-3f1a49caecd0","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1ddbb4c6-c2c6-44f0-a573-89761ca44d81","type":"Line"},"selection_glyph":null},"id":"95b40be2-6a0d-49c2-8f70-65be16eec2f9","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"80a4c831-3c58-4655-b846-84722995e756","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ba0c930-ba68-4122-9565-f5140105e155","type":"Square"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"olive"},"line_alpha":{"value":0.5},"line_color":{"value":"olive"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac7b8c2f-705f-4b77-a9af-0d9aab05182c","type":"Square"},{"attributes":{"dimension":1,"plot":{"id":"48791edc-c0bd-4498-881a-dc332d725641","subtype":"Figure","type":"Plot"},"ticker":{"id":"c93c8eb0-d45a-48d2-abfa-571b23bb712b","type":"BasicTicker"}},"id":"6eee4305-111f-464a-882a-c9986159c37f","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[2
"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.2},"start_angle":{"units":"rad","value":0.4},"x":{"field":"x"},"y":{"field":"y"}},"id":"646f7673-d0cd-4dff-afd1-42c37e28422d","type":"Wedge"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3],"y":[1,2,3]}},"id":"7ded5bad-cb47-425a-96b6-08f55b8a4b76","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8852680b-0e60-4b81-8758-f894a92019f0","type":"Patch"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ba0c930-ba68-4122-9565-f5140105e155","type":"Square"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"olive"},"line_alpha":{"value":0.5},"line_color":{"value":"olive"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac7b8c2f-705f-4b77-a9af-0d9aab05182c","type":"Square"},{"attributes":{"dimension":1,"plot":{"id":"48791edc-c0bd-4498-881a-dc332d725641","subtype":"Figure","type":"Plot"},"ticker":{"id":"c93c8eb0-d45a-48d2-abfa-571b23bb712b","type":"BasicTicker"}},"id":"6eee4305-111f-464a-882a-c9986159c37f","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.0,3.5,3.0,4.0],"y":[5,7,5]}},"id":"2c9ff23f-eff7-4c3c-a271-72efc618ea8f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.5},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"40073330-6cf5-49d2-adf0-32ef37c6c882","type":"Patch"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.5},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f4d6016-a5d4-40d8-9c3f-c414673bf9a7","type":"Patch"},{"attributes":{"direction":"clock","end_angle":{"units":"rad","value":4.8},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[16]</strong>&gt;</code></p>

# %% [markdown]
# As you can see, there are a number of different types of glyphs that can be added to Bokeh plots to represent your data. They include:
#
#     - asterisk()
#     - circle()
#     - circle_cross()
#     - circle_x()
#     - cross()
#     - diamond()
#     - diamond_cross()
#     - inverted_triangle()
#     - square()
#     - square_cross()
#     - square_x()
#     - triangle()
#     - x()

# %% [markdown]
# For a comprehensive description of the types of <i>parameters, keyword arguments</i>, and <i>other parameters</i> of each of the above glyphs, please refer to the online documentation for the <i>bokeh.plotting</i> interface here: http://bokeh.pydata.org/en/latest/docs/reference/plotting.html
#
# One slightly different example of glyph-plotting in this interface is the idea of using a single method for plotting multiple glyphs. An example of this is the <i>multi_line()</i> method which allows the user to add more than one <i>line</i> glyph by passing in a <i>list of lists</i> for the set of x co-ordinates and y co-ordinates for all lines. Similarly, the lines' attributes are passed in as a list of values which correspond to each line. This is illustrated below:

# %%
#Create new plot
plot1 = figure(title="Multi-Line Example", plot_height=500, plot_width=500, x_axis_label='Time', y_axis_label='Temperature')

#Add muliple lines at once using multi_line() method:
plot1.multi_line([[1,2,3],[4,5,6]], [[1,2,3],[6,5,4]], line_width=[3, 5], line_color=["red", "blue"], line_alpha=[0.5, 0.7])

show(plot1)
# Out:
#     <div class="plotdiv" id="8a44470f-964c-4a97-9fea-db64fb812eea"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8a44470f-964c-4a97-9fea-db64fb812eea");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8a44470f-964c-4a97-9fea-db64fb812eea' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"606b1709-95bc-4e30-a462-5bad7a8eebd3":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c61aea57-7ab5-436e-a948-d616c8749e6d","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"7ded5bad-cb47-425a-96b6-08f55b8a4b76","type":"ColumnDataSource"},"glyph":{"id":"a0ba56b4-e745-4f67-915a-5a5769127ec0","type":"Wedge"},"hover_glyph":null,"nonselection_glyph":{"id":"dc63f8d7-d5a4-44ef-b022-f0aa603f0ea7","type":"Wedge"},"selection_glyph":null},"id":"b263b138-7daf-4e72-a551-6e4680dbdae5","type":"GlyphRenderer"},{"attributes":{},"id":"82bebbd5-29e4-447b-9b4f-508f8dfa75c4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"738e29d6-e3a6-4c34-92f2-39ffb246157b","subtype":"Figure","type":"Plot"}},"id":"ab7d763a-0f62-4589-9f31-6a37de6572c8","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"738e29d6-e3a6-4c34-92f2-39ffb246157b","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f80322f-b5a8-4be0-9516-4527860a17dc","type":"BasicTicker"}},"id":"bf2fe1af-b61d-4caf-a5d1-418c653bb019","type":"Grid"},{"attributes":{"plot":{"id":"37054d80-ed96-45f9-aadb-9f8db1f45d40","subtype":"Figure","type":"Plot"}},"id":"a12d73a0-1a26-4c66-82cf-c3beb947b273","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"589c438d-c6e3-45a8-95f0-3007e14f7838","type":"DataRange1d"},{"attributes":{"overlay":{"id":"b34cadac-3196-4f78-9821-4e2a53634cf8","type":"BoxAnnotation"},"plot":{"id":"48791edc-c0bd-4498-881a-dc332d725641","subtype":"Figure","type":"Plot"}},"id":"a0cb0cf7-809a-4e16-9f30-6d299cb4285a","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b34cadac-3196-4f78-9821-4e2a53634cf8","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"88f3dea7-fa0e-4918-8d68-fcbea0f235e8","type":"MultiLine"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.0,3.5,4.0,4.5],"y":[5,7,5,6]}},"id":"0b1ff9ea-c620-4b5b-8217-caadde23b2a9","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"37054d80-ed96-45f9-aadb-9f8db1f45d40","subtype":"Figure","type":"Plot"}},"id":"955b4ac1-b1b7-4907-acfe-e9630edf4aa3","type":"ResizeTool"},{"attributes":{"plot":{"id":"48791edc-c0bd-4498-881a-dc332d725641","subtype":"Figure","type":"Plot"}},"id":"f7540bb7-7e1a-4bff-8a81-7b2a9c78e667","type":"ResetTool"},{"attributes":{"callback":null},"id":"8eb4074a-3cc0-4caa-9d43-8e2427129ff4","type":"DataRange1d"},{"attributes":{"plot":{"id":"48791edc-c0bd-4498-881a-dc332d725641","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb482466-b618-42f8-88ef-c070d6656aa3","type":"BasicTicker"}},"id":"a5a0696f-d428-4950-89d6-b29f996761e4","type":"Grid"},{"attributes":{},"id":"06e4a3b4-228d-4999-ab8e-94f70f3c5311","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3],"y":[1,2,3]}},"id":"1595d65a-384d-43aa-b181-60c35ae0ea74","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.5},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fac91718-bc86-4b8d-8c5e-ad2089b0575d","type":"Patch"},{"attributes":{},"id":"6f80322f-b5a8-4be0-9516-4527860a17dc","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.0,3.5,4.0],"y":[5,7,5]}},"id":"5d3bab13-2084-4b23-9661-dabac1cc3e73","type":"ColumnDataSource ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[19]</strong>&gt;</code></p>

# %% [markdown]
# Another example of a multi-glyph method is <i>patches()</i> which generates multiple patches.
# > <b>Note:</b> <i>NaN</i> values can be passed to <i>line, multi_line, patch,</i> and <i>patches</i> glyphs. Doing so creates single logical objects which just have disjoint components when rendered. This is illustrated below:

# %%
#Create new plot
plot2 = figure(title="NaN Example", plot_height=500, plot_width=500, x_axis_label='Time', y_axis_label='Temperature')

#Add a line which passes through a NaN co-ordinate:
nan = float('nan')
plot2.line([1, 2, 3, nan, 4, 5], [6, 7, 5, 3, 4, 5], line_width=3, line_color="orange", line_alpha=0.5)

show(plot2)
# Out:
#     <div class="plotdiv" id="2cbcf55f-cbbd-4ccf-a386-31eb3e355cbb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2cbcf55f-cbbd-4ccf-a386-31eb3e355cbb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2cbcf55f-cbbd-4ccf-a386-31eb3e355cbb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0e565695-cb5f-4f85-aa96-f4483c68b0f8":{"roots":{"references":[{"attributes":{"below":[{"id":"0a413e0b-5c20-407b-9e42-979da0634f99","type":"LinearAxis"}],"left":[{"id":"55cd8968-7b19-448b-9209-bb0a3608d0f6","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"0a413e0b-5c20-407b-9e42-979da0634f99","type":"LinearAxis"},{"id":"9f435494-90b0-4069-a5de-fcda747fef7c","type":"Grid"},{"id":"55cd8968-7b19-448b-9209-bb0a3608d0f6","type":"LinearAxis
," ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[26]</strong>&gt;</code></p>

# %% [markdown]
# Bokeh automatically sets the data bounds of your plot according to the data you are examining. If you want to explicitly set the range yourself, there are two ways of doing so:
# 1. Use a <i>Range1d</i> object to give the start and end points for <i>x_range</i> or <i>y_range</i>. This object must be imported in from the <i>bokeh.models</i> interface.
# 2. More conveniently, pass these values in through parameters of the same name in the <i>figure()</i> method.
# See below for a demonstration of both approaches:

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import Range1d

output_notebook()

#Set x range using 'x_range' parameter of the figure() method 
p = figure(title="My Plot", plot_width=400, plot_height=400, x_range=(0, 20))

#Set y range using Range1d object
p.y_range = Range1d(0, 15)

#Add some triangle-shaped scatter markers
p.triangle([1, 2, 3, 4, 5], [2, 5, 8, 2, 7], size=10)

show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3b092114-2801-4150-96cf-562d2cb52d9d">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="2aa00f15-e37b-475b-b50a-7fad6568e778"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2aa00f15-e37b-475b-b50a-7fad6568e778");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2aa00f15-e37b-475b-b50a-7fad6568e778' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7afbcac7-2ad4-4e7f-a49e-7b414482a819":{"roots":{"references":[{"attributes":{"below":[{"id":"0a413e0b-5c20-407b-9e42-979da0634f99","type":"LinearAxis"}],"left":[{"id":"55cd8968-7b19-448b-9209-bb0a3608d0f6","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"0a413e0b-5c20-407b-9e42-979da0634f99","type":"LinearAxis"},{"id":"9f435494-90b0-4069-a5de-fcda747fef7c","type":"Grid"},{"id":"55cd8968-7b19-448b-9209-bb0a3608d0f6","type":"LinearAxis"},{"id":"451ddb8d-4acd-413d-aed1-83fdae927bca","type":"Grid"},{"id":"3239b3e5-cd0b-415a-a8d0-298f665b9488","type":"BoxAnnotation"},{"id":"62d00726-0fd7-4e1e-9b8c-8d2271565fb7","type":"GlyphRenderer"}],"title":"NaN Example","tool_events":{"id":"1692fb84-ee5f-4877-bd97-3213a1f5f450","type":"ToolEvents"},"tools":[{"id":"d84da5cf-1e2a-4f82-b07a-359efdbf3afc","type":"PanTool"},{"id":"07fdf134-20da-4c15-b493-0728d5ad7cde","type":"WheelZoomTool"},{"id":"3647c5ac-4002-4a18-9d07-69219b35aadb","type":"BoxZoomTool"},{"id":"3ad1626c-ae48-481b-86c2-1d167b1329f1","type":"PreviewSaveTool"},{"id":"9451dfb2-5ad3-487a-bc44-243961fe1d57","type":"ResizeTool"},{"id":"721ef65a-71da-4583-9c76-0155836192b9","type":"ResetTool"},{"id":"d0a1e0fb-034b-4cdf-848e-64d5766ea765","type":"HelpTool"}],"x_range":{"id":"31c50d61-85e9-4c59-8b40-f9e54468ddda","type":"DataRange1d"},"y_range":{"id":"1aaf6796-aaa9-485c-9530-083e9f934647","type":"DataRange1d"}},"id":"7e2ad84c-7ddf-478c-8534-1d09486caa90","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"3e9c15fa-b9fe-4c26-a568-26d423dcdb2b","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c61aea57-7ab5-436e-a948-d616c8749e6d","type":"BoxAnnotation"},{"attributes":{},"id":"d28fc2e2-2231-4f04-99b4-90c1404135e9","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"7ded5bad-cb47-425a-96b6-08f55b8a4b76","type":"ColumnDataSource"},"glyph":{"id":"a0ba56b4-e745-4f67-915a-5a5769127ec0","type":"Wedge"},"hover_glyph":null,"nonselection_glyph":{"id":"dc63f8d7-d5a4-44ef-b022-f0aa603f0ea7","type":"Wedge"},"selection_glyph":null},"id":"b263b138-7daf-4e72-a551-6e4680dbdae5","type":"GlyphRenderer"},{"attributes":{},"id":"82f79e2b-e8d9-4c5f-8216-a67ec24e273d","type":"BasicTicker"},{"attributes":{"callback":null,"end":20},"id":"0554b59e-da7e-4fe6-a877-c5b8532c2511","type":"Range1d"},{"attributes":{},"id":"cb482466-b618-42f8-88ef-c070d6656aa3","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"88f3dea7-fa0e-4918-8d68-fcbea0f235e8","type":"MultiLine"},{"attributes":{"plot":{"id":"37054d80-ed96-45f9-aadb-9f8db1f45d40","subtype":"Figure","type":"Plot"}},"id":"955b4ac1-b1b7-4907-acfe-e9630edf4aa3","type":"ResizeTool"},{"attributes":{"callback":null},"id":"ddb08fd4-c4ae-4069-8b0c-8127ddf165dd","type":"DataRange1d"},{"attributes":{"formatter":{"id":"aad482ec-b591-4b52-9a7f-1b41114a0cd2","type":"BasicTickFormatter"},"plot":{"id":"69b45754-b7ef-4e85-82db-fc59ca8731f3","subtype":"Figure","type":"Plot"},"ticker":{"id":"def3c58e-5d5c-419a-afe2-8c825edd636c","type":"BasicTicker"}},"id":"91bf9002-f66b-41c4-9507-feee86e711fb","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3],"y":[1,2,3]}},"id":"1595d65a-384d-43aa-b181-60c35ae0ea74","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.0,3.5,4.0],"y":[5,7,5]}},"id":"5d3bab13-2084-4b23-9661-dabac1cc3e73","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"ad8718c6-1c83-433e-804f-464c320cb5ba","subtype":"Figure","type":"Plot"},"ticker":{"id":"8bf9b95c-0ab7-4445-9626-97bec0dccc70","type":"BasicTicker"}},"id":"5acbbd49-8ef9 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[30]</strong>&gt;</code></p>

# %% [markdown]
# You may not always want to use the default axis types generated by Bokeh when you create a plot. For example, if you want the labels of the y-axis to be letters rather than numbers, you can do so as follows:

# %%
factors = ["a", "b", "c", "d", "e", "f", "g", "h"]
x_points = [32, 10, 73, 22, 18, 42, 66, 54]

output_notebook()

plot3 = figure(y_range=factors, plot_width=400, plot_height=400)

plot3.square(x_points, factors, size=10, fill_color="yellow", line_color="green", line_width=3)

show(plot3)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="303c0d01-04cd-4afe-8584-0ac3d6a225cb">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="e15bf7f9-1fda-42cb-b4ea-6d84ba5cfe17"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e15bf7f9-1fda-42cb-b4ea-6d84ba5cfe17");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e15bf7f9-1fda-42cb-b4ea-6d84ba5cfe17' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6e289ca9-23b9-437a-aa14-2c3319a1496f":{"roots":{"references":[{"attributes":{"below":[{"id":"0a413e0b-5c20-407b-9e42-979da0634f99","type":"LinearAxis"}],"left":[{"id":"55cd8968-7b19-448b-9209-bb0a3608d0f6","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"0a413e0b-5c20-407b-9e42-979da0634f99","type":"LinearAxis"},{"id":"9f435494-90b0-4069-a5de-fcda747fef7c","type":"Grid"},{"id":"55cd8968-7b19-448b-9209-bb0a3608d0f6","type":"LinearAxis"},{"id":"451ddb8d-4acd-413d-aed1-83fdae927bca","type":"Grid"},{"id":"3239b3e5-cd0b-415a-a8d0-298f665b9488","type":"BoxAnnotation"},{"id":"62d00726-0fd7-4e1e-9b8c-8d2271565fb7","type":"GlyphRenderer"}],"title":"NaN Example","tool_events":{"id":"1692fb84-ee5f-4877-bd97-3213a1f5f450","type":"ToolEvents"},"tools":[{"id":"d84da5cf-1e2a-4f82-b07a-359efdbf3afc","type":"PanTool"},{"id":"07fdf134-20da-4c15-b493-0728d5ad7cde","type":"WheelZoomTool"},{"id":"3647c5ac-4002-4